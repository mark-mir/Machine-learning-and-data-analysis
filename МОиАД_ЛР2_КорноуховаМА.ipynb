# %% [markdown]
# #Задание 2
# #Визуальный анализ данных
# Вариант 12
#
# **Цель работы**: изучить программные средства, используемые для визуализации
# наборов данных.
#
# Проанализируем датасет *Hotel Reservations.csv*. Датасет содержит различную информацию о бронированиях отелей. Набор данных включает следующие атрибуты:
# Booking ID – уникальный идентификатор каждого бронирования
# - no_of_adults – количество взрослых
# - no_of_children – количество детей
# - no_of_weekend_nights – количество ночей в выходные дни (суббота или воскресенье), которые гость провел или забронировал для проживания в отеле
# - no_of_week_nights – количество ночей в неделю (с понедельника по пятницу),
# в течение которых гость останавливался или забронировал номер в отеле
# - type_of_meal_plan – тип плана питания, забронированного клиентом:
# - required_car_parking_space – требуется ли клиенту место для парковки автомобиля (0 – Нет, 1 – Да)
# - room_type_reserved – тип номера, зарезервированного клиентом. Значения
# зашифрованы (кодированы) INN Hotels
# - lead_time – количество дней между датой бронирования и датой прибытия
# - Arrival_year – год прибытия
# - Arrival_month – месяц даты прибытия
# - Arrival_date – дата месяца
# - marketsegmenttype – обозначение сегмента рынка.
# - repeat_guest – является ли клиент постоянным гостем? (О – Нет, 1 – Да)
# - no_of_previous_cancellations – количество предыдущих бронирований, которые были отменены клиентом до текущего бронирования
# - no_of_previous_bookings_not_canceled – количество предыдущих бронирований, не отмененных клиентом до текущего бронирования
# - avg_price_per_room – средняя цена за сутки бронирования; цены на номера являются динамическими (в евро)
# - no_of_special_requests – общее количество специальных запросов, сделанных
# клиентом (например, высокий этаж, вид из номера и т.д.)
# - booking status – флаг, указывающий, было ли отменено бронирование или нет
# (целевая переменная)

# %% [markdown]
# ##1. Импортируем необходимые бибилиотеки

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ##2. Импортируем набор данных из файла и помещаем его в объект DataFrame

# %%
data = pd.read_csv("/content/sample_data/Hotel Reservations.csv")
data.head()
# Out:
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# ...

# %% [markdown]
# #3. Получим сводную информацию по датафрейму

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# #4. Визуализация количественных признаков

# %% [markdown]
# Визуализация распределения простого количественного признака "arrival_month".

# %%
data['arrival_month'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Визуализация распределения каждого количественного признака.

# %%
data.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'no_of_adults'}>,
#         <Axes: title={'center': 'no_of_children'}>,
#         <Axes: title={'center': 'no_of_weekend_nights'}>,
#         <Axes: title={'center': 'no_of_week_nights'}>],
#        [<Axes: title={'center': 'required_car_parking_space'}>,
#         <Axes: title={'center': 'lead_time'}>,
#         <Axes: title={'center': 'arrival_year'}>,
#         <Axes: title={'center': 'arrival_month'}>],
#        [<Axes: title={'center': 'arrival_date'}>,
#         <Axes: title={'center': 'repeated_guest'}>,
#         <Axes: title={'center': 'no_of_previous_cancellations'}>,
#         <Axes: title={'center': 'no_of_previous_bookings_not_canceled'}>],
#        [<Axes: title={'center': 'avg_price_per_room'}>,
#         <Axes: title={'center': 'no_of_special_requests'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# Визуализация распределения простого количественного признака "arrival_month" с использованием matplotlib.

# %%
hist = data['arrival_month'].value_counts()
plt.bar(hist.index, hist)

# %% [markdown]
# Построение диаграммы типа "ящик с усами" с использованием Seaborn. По диаграмме можно определить медиану, квартили, интерквартильный размах, выбросы.

# %%
sns.boxplot(data['avg_price_per_room'])
# Out:
# <Axes: ylabel='avg_price_per_room'>

# %% [markdown]
# #5. Визуализация категориальных признаков

# %% [markdown]
# Категориальными признаками в анализируемом наборе данных являются признаки type_of_meal_plan, room_type_reserved, market_segment_type, booking_status (фактически является логическим).

# %% [markdown]
# Ниже представлен график типа countplot() из библиотеки Seaborn, который строит диаграмму, но не по сырым данным, а по рассчитанному количеству разных значений.

# %%
data['booking_status'].value_counts()
# Out:
# booking_status
# Not_Canceled    24390
# Canceled        11885
# Name: count, dtype: int64

# %%
sns.countplot(data, x='booking_status', hue='booking_status')
plt.show()

# %% [markdown]
# Гистограмма трёх популярных месяцев бронирования

# %%
sns.countplot(data[data['arrival_month'].isin(data['arrival_month'].value_counts().head(3).index)], x='arrival_month', hue='arrival_month')
# Out:
# <Axes: xlabel='arrival_month', ylabel='count'>

# %% [markdown]
# Гистограмма для всех месяцев

# %%
fig = plt.subplots(figsize=(15,8))
sns.countplot(data, x='arrival_month', hue='arrival_month')
# Out:
# <Axes: xlabel='arrival_month', ylabel='count'>

# %% [markdown]
# Столбчатая диаграмма

# %%
fig = plt.subplots(figsize=(15,8))
hist = data['arrival_month'].value_counts()
plt.bar(hist.index, hist)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# #6. Визуализация взаимосвязанных признаков

# %%
data.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
data_copy = data[['avg_price_per_room','booking_status']]
data_copy
# Out:
#        avg_price_per_room booking_status
# 0                   65.00   Not_Canceled
# 1                  106.68   Not_Canceled
# 2                   60.00       Canceled
# 3                  100.00       Canceled
# 4                   94.50       Canceled
# ...                   ...            ...
# 36270              167.80   Not_Canceled
# 36271               90.95       Canceled
# 36272               98.39   Not_Canceled
# 36273               94.50       Canceled
# 36274              161.67   Not_Canceled
#
# [36275 rows x 2 columns]

# %%
data_copy.hist(figsize=(8,8))
# Out:
# array([[<Axes: title={'center': 'avg_price_per_room'}>]], dtype=object)

# %% [markdown]
# #7. Корреляция признаков

# %% [markdown]
# Построим матрицу корреляции

# %%
data.corr(numeric_only=True)
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# required_car_parking_space                0.011429        0.034244
# lead_time                                 0.097287       -0.047091
# arrival_year                              0.076719        0.045983
# arrival_month                             0.021841       -0.003076
# arrival_date                              0.026338        0.025482
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# ...

# %%
sns.heatmap(data.corr(numeric_only=True), cmap=plt.cm.PuBuGn)
# Out:
# <Axes: >

# %% [markdown]
# Из матрицы корреляции видно, что признаки 'repeated_guest' и 'no_of_previous_cancellations' имеют сильную связь.
